# %%
import pandas as pd
pd.read_csv('data.csv')
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
import translate

# %%
import pandas

# %%
import pandas as pd
dataframe = pd.read_csv('data.csv')

# %%
dataframe
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dataframe.shape
# Out:
# (18207, 89)

# %%
dataframe.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
dataframe.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
dataframe['Overall'].hist()

# %%
dataframe.sort_values("Age", ascending=False)
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 4741         4741  140029       O. Pérez   45
# 18183       18183   53748  K. Pilkington   44
# 17726       17726   51963      T. Warner   44
# 10545       10545  140183    S. Narazaki   42
# 7225         7225  142998       C. Muñoz   41
# ...           ...     ...            ...  ...
# 17921       17921  246601     J. Rowland   16
# 17887       17887  246009       M. Tilio   16
# 15363       15363  245015      Y. Roemer   16
# 17881       17881  242165       R. Hauge   16
# 18206       18206  246269      G. Nugent   16
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 18183   https://cdn.sofifa.org/players/4/19/53748.png            England
# 17726   https://cdn.sofifa.org/players/4/19/51963.png  Trinidad & Tobago
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# ...

# %%
df.sort_values("Age", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9408bfff95fc> in <module>
# ----> 1 df.sort_values("Age", ascending=False)
#
# NameError: name 'df' is not defined

# %%
dataframe.sort_values("Age", ascending=False).head()

# %%
dataframe.sort_values("Age"> 39, ascending=False).head()

# %%
dataframe[dataframe["Age"]>28].sort_values("Potential", ascending=False).head()

# %%
dataframe[dataframe["Overall"]>85].sort_values("Release Clause")
# Out:
#     Unnamed: 0      ID             Name  Age  \
# 58          58  208722          S. Mané   26
# 8            8  155862     Sergio Ramos   32
# 61          61  201942  Roberto Firmino   26
# 29          29  198219       L. Insigne   27
# 20          20  189511  Sergio Busquets   29
# ..         ...     ...              ...  ...
# 12          12  182493         D. Godín   32
# 44          44  201024     K. Koulibaly   27
# 53          53  168651       I. Rakitić   30
# 28          28  198710     J. Rodríguez   26
# 38          38  167664       G. Higuaín   30
#
#                                              Photo Nationality  \
# 58  https://cdn.sofifa.org/players/4/19/208722.png     Senegal
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 61  https://cdn.sofifa.org/players/4/19/201942.png      Brazil
# 29  https://cdn.sofifa.org/players/4/19/198219.png       Italy
# 20  https://cdn.sofifa.org/players/4/19/189511.png       Spain
# ...

# %%
dataframe.sort_values(['Value'] & ['Wage'], ascending=[False,False]).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-5ef492b3c877> in <module>
# ----> 1 dataframe.sort_values(['Value'] & ['Wage'], ascending=[False,False]).head()
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %%
df1 = pd.DataFrame(dataframe, columns=['Name', 'Wage', 'Value'])

# %%
df1.head(50)
# Out:
#                  Name   Wage    Value
# 0            L. Messi  €565K  €110.5M
# 1   Cristiano Ronaldo  €405K     €77M
# 2           Neymar Jr  €290K  €118.5M
# 3              De Gea  €260K     €72M
# 4        K. De Bruyne  €355K    €102M
# 5           E. Hazard  €340K     €93M
# 6           L. Modrić  €420K     €67M
# 7           L. Suárez  €455K     €80M
# 8        Sergio Ramos  €380K     €51M
# 9            J. Oblak   €94K     €68M
# 10     R. Lewandowski  €205K     €77M
# 11           T. Kroos  €355K   €76.5M
# 12           D. Godín  €125K     €44M
# 13        David Silva  €285K     €60M
# 14           N. Kanté  €225K     €63M
# 15          P. Dybala  €205K     €89M
# 16            H. Kane  €205K   €83.5M
# 17       A. Griezmann  €145K     €78M
# 18      M. ter Stegen  €240K     €58M
# 19        T. Courtois  €240K   €53.5M
# 20    Sergio Busquets  €315K   €51.5M
# 21          E. Cavani  €200K     €60M
# 22           M. Neuer  €130K     €38M
# 23          S. Agüero  €300K   €64.5M
# ...

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace(['\€'],'', regex=True).apply(value_to_float)
value = df1['Value'].replace(['\€'],'', regex=True).apply(value_to_float)
df1['Value'] = value
df1['Wage'] = wage
df1['difference']= df1['Value'] - df1['Wage']

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace(['\€'],'', regex=True).apply(value_to_float)
value = df1['Value'].replace(['\€'],'', regex=True).apply(value_to_float)
df1['Value'] = value
df1['Wage'] = wage
df1['difference']= df1['Value'] - df1['Wage']

# %%
df1
# Out:
#                      Name      Wage        Value   difference
# 0                L. Messi  565000.0  110500000.0  109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0   76595000.0
# 2               Neymar Jr  290000.0  118500000.0  118210000.0
# 3                  De Gea  260000.0   72000000.0   71740000.0
# 4            K. De Bruyne  355000.0  102000000.0  101645000.0
# ...                   ...       ...          ...          ...
# 18202        J. Lundstram    1000.0      60000.0      59000.0
# 18203  N. Christoffersson    1000.0      60000.0      59000.0
# 18204           B. Worman    1000.0      60000.0      59000.0
# 18205      D. Walker-Rice    1000.0      60000.0      59000.0
# 18206           G. Nugent    1000.0      60000.0      59000.0
#
# [18207 rows x 4 columns]

# %%
df1.sort_values("difference", ascending=False).head(15)
# Out:
#                  Name      Wage        Value   difference
# 2           Neymar Jr  290000.0  118500000.0  118210000.0
# 0            L. Messi  565000.0  110500000.0  109935000.0
# 4        K. De Bruyne  355000.0  102000000.0  101645000.0
# 5           E. Hazard  340000.0   93000000.0   92660000.0
# 15          P. Dybala  205000.0   89000000.0   88795000.0
# 16            H. Kane  205000.0   83500000.0   83295000.0
# 25          K. Mbappé  100000.0   81000000.0   80900000.0
# 7           L. Suárez  455000.0   80000000.0   79545000.0
# 17       A. Griezmann  145000.0   78000000.0   77855000.0
# 10     R. Lewandowski  205000.0   77000000.0   76795000.0
# 1   Cristiano Ronaldo  405000.0   77000000.0   76595000.0
# 11           T. Kroos  355000.0   76500000.0   76145000.0
# 31         C. Eriksen  205000.0   73500000.0   73295000.0
# 30               Isco  315000.0   73500000.0   73185000.0
# 3              De Gea  260000.0   72000000.0   71740000.0

# %%
df1['difference'].hist()

# %%
df1
# Out:
#                      Name      Wage        Value   difference
# 0                L. Messi  565000.0  110500000.0  109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0   76595000.0
# 2               Neymar Jr  290000.0  118500000.0  118210000.0
# 3                  De Gea  260000.0   72000000.0   71740000.0
# 4            K. De Bruyne  355000.0  102000000.0  101645000.0
# ...                   ...       ...          ...          ...
# 18202        J. Lundstram    1000.0      60000.0      59000.0
# 18203  N. Christoffersson    1000.0      60000.0      59000.0
# 18204           B. Worman    1000.0      60000.0      59000.0
# 18205      D. Walker-Rice    1000.0      60000.0      59000.0
# 18206           G. Nugent    1000.0      60000.0      59000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph= sns.scatterplot(x='Wage',y='Value',data=df1)
graph

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name"),]
)


p = figure(title='Fifa 2019', x_axis_label='Wage', y_axis_label='Value', plot_width=700, plot_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
